# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
raw_data = pd.read_csv("./data/raw_dataset.csv")
dataset = pd.read_csv("./data/clean_dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 raw_data = pd.read_csv("./data/raw_dataset.csv")
#       2 dataset = pd.read_csv("./data/clean_dataset.csv")
#
# NameError: name 'pd' is not defined

# %%
# dataset = pd.get_dummies(dataset, columns=["subtype"])

# %%
dataset.tail()
# Out:
#                   locality       type    price  living_area  land_area  \
# 14608  Sint-Pieters-Woluwe      house  2250000          365       1571
# 14609  Sint-Pieters-Woluwe      house  2250000          375       1571
# 14610                Ukkel  apartment  2250000          330          0
# 14611  Sint-Pieters-Woluwe      house  2250000          365       1571
# 14612                Ukkel      house  2250000          410        961
#
#        facades  state  furnished  terrace  garden  ...  subtype_ground-floor  \
# 14608        4      4      False     True    True  ...                 False
# 14609        4      7      False     True    True  ...                 False
# 14610        4      6      False     True    True  ...                 False
# 14611        4      7      False     True    True  ...                 False
# 14612        4      7      False     True    True  ...                 False
#
#        subtype_loft  subtype_mansion  subtype_master-house  \
# ...

# %%
trim = dataset.iloc[10000:,:]
trim.corr(numeric_only = True).sort_values(by="price", ascending = False).price[1:]
# Out:
# living_area               0.305201
# pool                      0.244924
# land_area                 0.235660
# subtype_villa             0.194661
# terrace                   0.140801
# subtype_master-house      0.080780
# subtype_mansion           0.074917
# facades                   0.071640
# subtype_mixed-building    0.071275
# subtype_penthouse         0.064245
# furnished                 0.057757
# garden                    0.047403
# subtype_cottage           0.015828
# subtype_loft              0.015585
# subtype_triplex           0.003762
# subtype_studio           -0.008396
# subtype_chalet           -0.010306
# subtype_duplex           -0.012427
# subtype_ground-floor     -0.014370
# subtype_bungalow         -0.036025
# state                    -0.039784
# subtype_apartment        -0.045225
# subtype_residence        -0.167095
# Name: price, dtype: float64

# %%
print(dataset.shape)
dataset.head(10)
# Out:
# (24081, 15)
#           Locality Type of property Subtype of property   Price  \
# 0            Namur        apartment              studio  125000
# 1        Quaregnon            house           residence  125000
# 2           Dinant        apartment              studio  125000
# 3        Rochefort        apartment           apartment  125000
# 4              Ans            house           residence  125000
# 5          Jemelle            house           residence  125000
# 6    Saint-Nicolas            house           residence  125000
# 7           Manage        apartment           apartment  125000
# 8       Schaarbeek        apartment              studio  125000
# 9  Hastière-Lavaux            house            bungalow  125000
#
#    Number of rooms  Living Area  Terrace Area  Garden Area  \
# 0              NaN         25.0           NaN          NaN
# 1              4.0        155.0          24.0        240.0
# 2              NaN         45.0           NaN          NaN
# ...

# %%
dataset.locality.unique()
# Out:
# <StringArray>
# [          'Namur',       'Quaregnon',          'Dinant',          'Manage',
#       'Schaarbeek', 'Hastière-Lavaux',         'Bertrix',    'Petit-Hallet',
#       'Marcinelle',        'Brussels',
#  ...
#         'Everberg',     'Massenhoven',  'Virginal-Samme',      'Hennuyères',
#        'Monstreux',             'Pry',       'La Gleize',       'Baisy-Thy',
#          'Glabais',     'Sivry-Rance']
# Length: 1105, dtype: str

# %%
dataset = pd.get_dummies(dataset, columns=["type"])

# %%
dataset.corr(numeric_only = True).sort_values(by="price", ascending = False).price[1:]
# Out:
# living_area       0.458816
# rooms             0.372542
# facades           0.206298
# land_area         0.192363
# terrace           0.185476
# garden            0.149725
# type_house        0.114491
# pool              0.111397
# furnished         0.003934
# type_apartment   -0.114491
# Name: price, dtype: float64
