# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

print("OK")
# Out:
# OK

# %%
raw_data = pd.read_csv("./data/raw_dataset.csv")
dataset = pd.read_csv("./data/clean_dataset.csv")
colors = {"color1": "#127FC3",
         "color3": "#11C5D9",
         "color4": "#47C550",
         "color2": "#F2D544",
         "facecolor": "#F7F7F7"}
print("OK")
# Out:
# OK

# %% [markdown]
# # Other

# %%
raw_data.isna().sum()
# Out:
# Locality                     0
# Type of property             0
# Subtype of property          0
# Price                      513
# Number of rooms            541
# Living Area               1773
# Terrace Area             16413
# Garden Area              21076
# Surface of the land      13331
# Number of facades         6305
# State of the building     6113
# Furnished                    0
# Terrace                      0
# Garden                       0
# Swimming pool                0
# dtype: int64

# %%
dataset
# Out:
#        index       type    subtype    price  Number of rooms  living_area  \
# 0          0      house  residence    90000                2          120
# 1          1  apartment  apartment    90000                1           49
# 2          2      house  residence    90000                1          165
# 3          3      house  residence    90000                3          115
# 4          4      house  residence    90000                2          113
# ...      ...        ...        ...      ...              ...          ...
# 14262  14426      house      villa  2250000                5          365
# 14263  14427      house      villa  2250000                5          375
# 14264  14428  apartment  penthouse  2250000                4          330
# 14265  14429      house      villa  2250000                5          365
# 14266  14430      house      villa  2250000                6          410
#
#        land_area  facades  state  furnished  terrace  garden   pool  \
# 0            235        2      2      False     True    True  False
# 1              0        2      6      False     True   False  False
# 2           1410        4      2      False    False    True  False
# 3            269        2      2      False     True   False  False
# 4            170        2      2      False     True    True  False
# ...          ...      ...    ...        ...      ...     ...    ...
# 14262       1571        4      4      False     True    True  False
# 14263       1571        4      7      False     True    True  False
# 14264          0        4      6      False     True    True   True
# 14265       1571        4      7      False     True    True  False
# 14266        961        4      7      False     True    True  False
#
#                         region         municipality
# 0               Walloon Region             Chièvres
# 1               Walloon Region            Charleroi
# 2               Walloon Region  Frasnes-lez-Anvaing
# 3               Walloon Region                 Dour
# 4               Walloon Region                 Dour
# ...                        ...                  ...
# 14262  Brussels-Capital Region  Woluwe-Saint-Pierre
# 14263  Brussels-Capital Region  Woluwe-Saint-Pierre
# 14264  Brussels-Capital Region                Uccle
# 14265  Brussels-Capital Region  Woluwe-Saint-Pierre
# 14266  Brussels-Capital Region                Uccle
#
# [14267 rows x 15 columns]

# %%
rooms = dataset.iloc[100:-100,3:6]
rooms.price = rooms.price.apply(lambda x: round(x / 100000) * 100000)
rooms = rooms.groupby("price").mean().reset_index()
print("Correlation between Living area and Number of rooms is: ",
      rooms.corr().iloc[1,2] * 100 // 1 / 100, sep = "")
# Out:
# Correlation between Living area and Number of rooms is: 0.95

# %%
fig, ax = plt.subplots()
l1, = ax.plot(rooms.price, rooms.living_area, color = colors["color1"], label = "Living area")
ax2 = ax.twinx()
l2, = ax2.plot(rooms.price, rooms["Number of rooms"], color = colors["color2"], label = "Number of rooms")
ax.legend(handles = [l1, l2])
ax.set_xlabel("Price")
ax.ticklabel_format(style="plain", axis = "x")
ax.tick_params(axis="x", rotation=45)
ax.set_ylabel("Area")
ax2.set_ylabel("Number of rooms")
plt.show()

# %% [markdown]
# For this reason Number of rooms was removed from data. Because as price depended on Living area - it is same way depended on Number of rooms.

# %% [markdown]
# ## Living area to Price ratio

# %%
house_living_area = dataset[dataset.type == "house"].groupby("living_area")["price"].mean().to_frame().reset_index().iloc[50:-50]
apartment_living_area = dataset[dataset.type == "apartment"].groupby("living_area")["price"].mean().to_frame().reset_index().iloc[50:-50]
fig, ax = plt.subplots()
ax.plot(house_living_area.living_area, house_living_area.price, linestyle = "", marker = "o", color=colors["color1"])
ax.plot(apartment_living_area.living_area, apartment_living_area.price, linestyle = "", marker = "o", color=colors["color2"])
ax.legend(["House", "Apartment"])
ax.set_xlabel("Living area (m^2)")
ax.set_ylabel("Price")
ax.ticklabel_format(style='plain', axis='y')
ax.set_title("Living area to Price ratio")
ax.set_facecolor(colors["facecolor"])
plt.show()

# %%
print("Correlation between Living area and Price for houses is: ",
      house_living_area.corr().iloc[0, 1] * 100 // 1 / 100, sep = "")
print("Correlation between Living area and Price for apartments is: ",
      apartment_living_area.corr().iloc[0, 1] * 100 // 1 / 100, sep = "")
# Out:
# Correlation between Living area and Price for houses is: 0.7
# Correlation between Living area and Price for apartments is: 0.74

# %% [markdown]
# ## Price based on Subtype

# %% [markdown]
# Checking if **STD** is lower than **MEAN**.

# %%
temp = dataset.groupby("subtype")["price"].agg(["std", "mean"])
temp.iloc[:,:] /= 1000
temp
# Out:
#                        std         mean
# subtype
# apartment       213.127332   339.361342
# bungalow        118.409251   342.454545
# chalet          109.047979   232.887097
# cottage         319.355606   547.416049
# duplex          227.636907   380.773796
# ground-floor    190.489423   333.665011
# loft            292.508402   494.618395
# mansion         436.643038  1237.500000
# master-house    433.594169   688.747464
# mixed-building  357.706259   487.405877
# penthouse       369.387745   614.109226
# residence       237.042747   389.038505
# studio           68.194179   188.407315
# triplex         260.896715   380.167442
# villa           421.031040   732.447323

# %% [markdown]
# Results: **STD** gives lower values than **MEAN**. So we can use **MEAN** to create Bar Chart for Subtypes and Prices.

# %%
subtypes = dataset.groupby(["type", "subtype"])["price"].mean().to_frame().reset_index().sort_values("price")
subtypes["color"] = subtypes["type"].apply(lambda x: colors["color1"] if x == "house" else colors["color2"])
legend = [
    Patch(color=colors["color1"], label = "House"),
    Patch(color=colors["color2"], label = "Apartment")
]
fig, ax = plt.subplots()
ax.bar(subtypes.subtype, subtypes.price, color=subtypes.color)
ax.legend(handles = legend)
ax.set_ylabel("Price")
ax.ticklabel_format(style="plain", axis="y")
ax.set_facecolor(colors["facecolor"])
plt.xticks(rotation=90)
plt.show()
